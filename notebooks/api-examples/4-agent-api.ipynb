# %% [markdown]
# <a href="https://colab.research.google.com/github/vectara/example-notebooks/blob/main/notebooks/api-examples/4-agent-api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vectara Agent API Examples
#
# This notebook demonstrates how to use Vectara's Agent REST APIs directly to create and interact with AI agents.
#
# You'll learn how to:
# 1. Create an agent with custom instructions
# 2. Create agent sessions for conversations
# 3. Send messages to agents and get responses
# 4. Use streaming for real-time responses
# 5. Manage conversation history
# 6. Work with tools and tool servers

# %% [markdown]
# ## About Vectara
#
# [Vectara](https://vectara.com/) is the Agent Platform for trusted enterprise AI: a unified Agentic RAG platform with built-in multi-modal retrieval, orchestration, and always-on governance. Deploy it on-prem (air-gapped), in your VPC, or as SaaS. Vectara agents deliver grounded answers and safe actions with source citations, step-level audit trails, fine-grained access controls, and real-time policy and factual-consistency enforcement, so teams ship faster with lower risk, and with trusted, production-grade AI agents at scale.
#
# Vectara provides a complete API-first platform for building production RAG and agentic applications:
#
# - **Simple Integration**: RESTful APIs and SDKs (Python, JavaScript) for quick integration into any stack
# - **Flexible Deployment**: Choose SaaS, VPC, or on-premises deployment based on your security requirements
# - **Multi-Modal Support**: Index and search across text, tables, and images from PDFs, documents, and structured data
# - **Advanced Retrieval**: Hybrid search combining semantic and keyword matching with state-of-the-art reranking
# - **Grounded Generation**: LLM responses with citations and factual consistency scores to reduce hallucinations
# - **Enterprise-Ready**: Built-in access controls, audit logging, and compliance (SOC2, HIPAA) from day one

# %% [markdown]
# ## Getting Started
#
# This notebook assumes you've completed Notebooks 1-2, and potentially 3:
# - Notebook 1: Created two corpora (ai-research-papers and vectara-docs)
# - Notebook 2: Ingested AI research papers and Vectara documentation
# - Notebook 3: Queried the data with various techniques
#
# Now we'll create agents that can autonomously search and reason across this data.

# %% [markdown]
# ## Setup

# %%
# !pip install -q sseclient-py

# %%
import os
import requests
import json
import uuid
from datetime import datetime

# Get credentials from environment variables
api_key = os.environ['VECTARA_API_KEY']

# Get corpus keys from environment (from Notebook 1)
research_corpus_key = 'tutorial-ai-research-papers'
docs_corpus_key = 'tutorial-vectara-docs'

# Base API URL
BASE_URL = "https://api.vectara.io/v2"

# Common headers
headers = {
    "x-api-key": api_key,
    "Content-Type": "application/json"
}

# %% [markdown]
# ## Step 1: Create a Basic Agent
#
# Create an agent with custom instructions that can search your corpus:

# %%
# Define agent configuration - this agent can access both corpora
# Agent structure uses steps with instructions and tool configurations
agent_name = "RAG Research Assistant"
agent_config = {
    "name": agent_name,
    "description": "Agent that can answer questions about RAG, embeddings, and retrieval from both research papers and documentation",
    "model": { "name": "gpt-4o" },
    "first_step_name": "main",
    "steps": {
        "main": {
            "instructions": [
                {
                    "type": "inline",
                    "name": "first set of instructions",
                    "template": """
You are an expert AI research assistant specializing in Retrieval Augmented Generation and AI Agents. 
You have access to both academic research papers and Vectara's technical documentation. 
Provide clear, accurate answers with citations. 
When answering, combine theoretical insights from research with practical implementation guidance from documentation.
                            """
                }
            ],
            "output_parser": {"type": "default"}
        }
    },
    
    "tool_configurations": {
        "research_paper_search": {
            "type": "corpora_search",
            "query_configuration": {
                "search": {
                    "corpora": [
                        {
                            "corpus_key": research_corpus_key
                        }
                    ]
                },
                "generation": {
                    "generation_preset_name": "vectara-summary-table-md-query-ext-jan-2025-gpt-4o",
                    "model_parameters": {
                        "llm_name": "gpt-4o",
                        "temperature": 0.0
                    }
                }
            }
        },
        "vectara_doc_search": {
            "type": "corpora_search",
            "query_configuration": {
                "search": {
                    "corpora": [
                        {
                            "corpus_key": docs_corpus_key
                        }
                    ]
                },
                "generation": {
                    "generation_preset_name": "vectara-summary-table-md-query-ext-jan-2025-gpt-4o",
                    "model_parameters": {
                        "llm_name": "gpt-4o",
                        "temperature": 0.0
                    }
                }
            }
        }

    }
}

# Inlined here to show the pagination pattern explicitly; notebooks 5+ import
# the same helper as vectara_utils.find_agents_by_name.
def find_agent_by_name(name):
    """Find an agent by name, handling pagination."""
    page_key = None
    while True:
        params = {'limit': 100}
        if page_key:
            params['page_key'] = page_key
        resp = requests.get(f"{BASE_URL}/agents", headers=headers, params=params)
        if resp.status_code != 200:
            break
        data = resp.json()
        for agent in data.get('agents', []):
            if agent.get('name') == name:
                return agent
        page_key = data.get('metadata', {}).get('page_key')
        if not page_key:
            break
    return None

# Check if agent already exists
print(f"Checking if agent '{agent_name}' already exists...")
agent_key = None
existing = find_agent_by_name(agent_name)
if existing:
    agent_key = existing['key']
    print(f"✓ Agent already exists!")
    print(f"  Agent Key: {agent_key}")
    print(f"  Agent Name: {existing['name']}")
    print(f"  Steps: {list(existing.get('steps', {}).keys())}")

# Create the agent only if it doesn't exist
if not agent_key:
    print(f"Creating new agent '{agent_name}'...")
    response = requests.post(f"{BASE_URL}/agents", headers=headers, json=agent_config)
    
    print(f"Status Code: {response.status_code}")
    if response.status_code == 201:
        agent_data = response.json()
        agent_key = agent_data["key"]
        print(f"✓ Agent Created!")
        print(f"  Agent Key: {agent_key}")
        print(f"  Agent Name: {agent_data['name']}")
        print(f"  Steps: {list(agent_data.get('steps', {}).keys())}")
    elif response.status_code == 409:
        # Agent was created between our check and create call; look it up again
        existing = find_agent_by_name(agent_name)
        if existing:
            agent_key = existing['key']
            print(f"✓ Agent already exists!")
            print(f"  Agent Key: {agent_key}")
        else:
            print(f"Error: Agent exists per API but could not be found in listing")
    else:
        print(f"Error: {response.text}")

# %% [markdown]
# ## Step 2: Create an Agent Session
#
# Sessions maintain conversation context across multiple turns:

# %%
# Create a new session with a unique name to allow reruns
session_name = f"Technical Support Chat {datetime.now().strftime('%Y%m%d-%H%M%S')}"
session_config = {
    "name": session_name,
    "metadata": {
        "user_type": "developer",
        "session_purpose": "api_questions"
    }
}

url = f"{BASE_URL}/agents/{agent_key}/sessions"
response = requests.post(url, headers=headers, json=session_config)

print(f"Status Code: {response.status_code}")
if response.status_code == 201:
    session_data = response.json()
    session_key = session_data["key"]
    print(f"✓ Session Created!")
    print(f"  Session Name: {session_name}")
    print(f"  Session Key: {session_key}")
else:
    print(f"Error: {response.text}")
# Out:
# Status Code: 201
# ✓ Session Created!
#   Session Name: Technical Support Chat 20260420-122616
#   Session Key: ase_technical_support_chat_20260420-122616_70cb

# %% [markdown]
# ## Step 3: Send Messages to the Agent
#
# Send a message and get a response:

# %%
# Send a message to the agent
# The correct format uses a messages array with message objects
message_data = {
    "messages": [
        {
            "type": "text",
            "content": "What is retrieval augmented generation and how can I implement it with Vectara?"
        }
    ],
    "stream_response": False
}

url = f"{BASE_URL}/agents/{agent_key}/sessions/{session_key}/events"
response = requests.post(url, headers=headers, json=message_data)

if response.status_code == 201:
    event_data = response.json()
    print(f"\nAgent Response:")
    # The response typically contains the assistant's message in the events
    if 'events' in event_data:
        for event in event_data['events']:
            if event.get('type') == 'agent_output':
                print(event.get('content', 'No content'))
    else:
        print(event_data)
else:
    print(f"Error: {response.text}")
# Out:
# Agent Response:
# Retrieval-Augmented Generation (RAG) is an innovative approach that combines both parametric and non-parametric memory for language generation tasks. This method allows language models to improve their outputs by accessing external sources of information in real-time. RAG is particularly effective for knowledge-intensive NLP tasks where it can enhance the accuracy and relevance of generated responses by drawing on both stored knowledge and live data retrieval [1][2][3].
#
# To implement RAG with Vectara, you can utilize their Query APIs to search data and generate AI-powered summaries. Vectara supports applications like enterprise search, chatbots, or knowledge bases by allowing developers to customize prompt templates with metadata. Through the Custom RAG Prompt Engine, developers can directly incorporate retrieved documents and their metadata into the prompt generation, offering flexibility in generating contextually grounded responses [2][4]. For further technical implementation, you can refer to Vectara's platform documentation on customizing prompts and using the query APIs [vectara_1][vectara_2][vectara_3][vectara_4].

# %% [markdown]
# ## Step 4: Multi-Turn Conversation
#
# The agent maintains conversation context automatically:

# %%
# First message
message_1 = {
    "messages": [
        {
            "type": "text",
            "content": "What is hybrid search?"
        }
    ],
    "stream_response": False
}

url = f"{BASE_URL}/agents/{agent_key}/sessions/{session_key}/events"
response = requests.post(url, headers=headers, json=message_1)

print("User: What is hybrid search?")

if response.status_code == 201:
    event_data = response.json()
    print(f"\nAgent Response:")
    if 'events' in event_data:
        for event in event_data['events']:
            if event.get('type') == 'agent_output':
                print(event.get('content', 'No content'))
    else:
        print(event_data)
else:
    print(f"Error: {response.text}")
    
print("\n" + "="*80 + "\n")
# Out:
# User: What is hybrid search?
#
# Agent Response:
# Hybrid search is a technique in information retrieval that combines both semantic (neural) and lexical (keyword-based) matching. This method addresses the limitations of solely using either approach by ensuring that exact terms such as SKUs, part numbers, and internal codenames are accurately retrieved [vectara_1]. By adjusting a parameter known as the lexical interpolation value, you can balance between neural and lexical search, with values ranging from 0.0 (purely neural search) to 1.0 (purely lexical search). Typical optimal values for hybrid search are between 0.01 and 0.1 [vectara_2][vectara_3].
#
# The integration of both approaches enhances retrieval accuracy by leveraging neural search's contextual understanding and keyword search's precision in exact term matching. This balance is crucial for applications requiring accurate retrieval of specific terms alongside semantic context comprehension [vectara_3].
#
# ================================================================================

# %%
# Follow-up message (agent remembers context)
message_2 = {
    "messages": [
        {
            "type": "text",
            "content": "What are its main benefits?"
        }
    ],
    "stream_response": False
}

response = requests.post(url, headers=headers, json=message_2)

print("User: What are its main benefits?")
if response.status_code == 201:
    event_data = response.json()
    print(f"\nAgent Response:")
    if 'events' in event_data:
        for event in event_data['events']:
            if event.get('type') == 'agent_output':
                print(event.get('content', 'No content'))
    else:
        print(event_data)
else:
    print(f"Error: {response.text}")
# Out:
# User: What are its main benefits?
#
# Agent Response:
# The main benefits of hybrid search in information retrieval are:
#
# 1. **Improved Retrieval Accuracy**: By combining semantic and lexical matching, hybrid search improves the accuracy of retrieval systems. This approach ensures that while context and meaning are considered (through semantic matching), exact terms are not overlooked (through lexical matching). This dual approach helps in retrieving not only contextually relevant results but also those that include exact match terms like SKUs and part numbers [vectara_1][vectara_3].
#
# 2. **Optimal Balance**: Hybrid search allows for adjusting the balance between neural and keyword-based search, enabling systems to fine-tune retrieval outputs based on specific use-case requirements. Users can customize the retrieval behavior by setting interpolation values, which facilitates a tailored search performance that meets diverse needs [vectara_2].
#
# 3. **Flexibility and Customization**: Users and developers can leverage parameters such as the lexical interpolation value to adjust the search process dynamically. This flexibility ensures that the search mechanism can be optimized for different scenarios, whether prioritizing broad contextual understanding or precise keyword matching [vectara_3].
#
# 4. **Versatility**: Hybrid search techniques can be applied across various domains, including enterprise applications, e-commerce, and digital libraries, where a mix of exact term requirements and contextual relevance is crucial.
#
# Overall, hybrid search offers a comprehensive and adaptable approach to information retrieval, improving both precision and recall in search results by leveraging the strengths of both neural and keyword-based methods.

# %%
# Another follow-up
message_3 = {
    "messages": [
        {
            "type": "text",
            "content": "Can you give me an example?"
        }
    ],
    "stream_response": False
}

response = requests.post(url, headers=headers, json=message_3)

print("User: Can you give me an example?")
if response.status_code == 201:
    event_data = response.json()
    print(f"\nAgent Response:")
    # The response typically contains the assistant's message in the events
    if 'events' in event_data:
        for event in event_data['events']:
            if event.get('type') == 'agent_output':
                print(event.get('content', 'No content'))
    else:
        print(event_data)
else:
    print(f"Error: {response.text}")
# Out:
# User: Can you give me an example?
#
# Agent Response:
# Certainly! Let's consider an e-commerce platform where users often search for products using specific terms, such as "Sony WH-1000XM4 headphones," as well as more general queries like "best noise-cancelling headphones."
#
# **Hybrid Search Example in E-commerce:**
#
# - **Lexical Matching**: When a user searches for the exact product model "Sony WH-1000XM4," lexical search ensures these precise terms are not lost. It retrieves listings that include this exact model number, which is crucial for users looking for a specific product.
#
# - **Semantic Matching**: For a more general query such as "best noise-cancelling headphones," semantic search interprets the user's intent, identifying products with high ratings and reviews within the noise-cancelling category, even if they don't explicitly mention "best" or "noise-cancelling" in the description.
#
# - **Hybrid Search in Action**: By using hybrid search, the platform can combine these capabilities. It retrieves the exact product listings using lexical matching while also showing other highly rated noise-cancelling headphones, leveraging semantic understanding. This approach ensures users find both the specific products they directly searched for and other relevant options they might be interested in.
#
# This combination enhances user satisfaction by making sure precise needs are met (through [vectara_1]), and broader user intents are also understood and served, thanks to hybrid search's flexibility [vectara_2][vectara_3].

# %% [markdown]
# ## Step 5: Streaming Responses
#
# Vectara's Agent API supports Server-Sent Events (SSE) for streaming responses in real time. Instead of waiting for the complete response, you can process text chunks, tool calls, and thinking events as they arrive. Set `stream_response: True` in your message payload to enable streaming.

# %%
import sseclient

# Send a message with streaming enabled
message_data = {
    "messages": [
        {
            "type": "text",
            "content": "Briefly explain how embeddings work in retrieval systems."
        }
    ],
    "stream_response": True
}

url = f"{BASE_URL}/agents/{agent_key}/sessions/{session_key}/events"
response = requests.post(url, headers=headers, json=message_data, stream=True)

print("Streaming response:\n")

# Streaming endpoints return 200 OK (not 201 Created like the non-streaming create-event calls above)
if response.ok:
    client = sseclient.SSEClient(response)
    for sse_event in client.events():
        try:
            event = json.loads(sse_event.data)
        except json.JSONDecodeError:
            continue
        event_type = event.get("type", "")

        if event_type == "streaming_agent_output":
            # Print each text chunk as it arrives
            print(event.get("content", ""), end="", flush=True)
        elif event_type == "streaming_agent_output_end":
            print("\n\n--- Stream complete ---")
        elif event_type == "tool_input":
            tool = event.get("tool_configuration_name", "unknown")
            print(f"[Calling tool: {tool}]")
        elif event_type == "tool_output":
            tool = event.get("tool_configuration_name", "unknown")
            print(f"[Tool response received: {tool}]")
        elif event_type == "thinking":
            print(f"[Thinking: {event.get('content', '')[:80]}...]")
else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# Streaming response:
#
# [Calling tool: research_paper_search]
# [Calling tool: vectara_doc_search]
# [Tool response received: research_paper_search]
# [Tool response received: vectara_doc_search]
# Embeddings in retrieval systems are used to convert documents or data into vector representations that capture their semantic content. These vector embeddings are essential for vector search, allowing retrieval systems to efficiently index and retrieve documents based on their semantic similarity.
#
# Here's a brief overview of how embeddings are used in retrieval systems:
#
# 1. **Vector Representation**: Embeddings transform data into vectors in a high-dimensional space, enabling the system to capture nuanced meanings and relationships between different pieces of data. This transformation facilitates understanding not just keyword matches, but contextual meanings as well [1].
#
# 2. **Indexing**: Once data is converted into vector embeddings, it can be indexed using techniques like Maximum Inner Product Search (MIPS) with tools like FAISS. These indices allow for fast and efficient retrieval by organizing the embeddings in a structure optimized for quick access [vectara_1].
#
# 3. **Semantic Clustering**: Embeddings allow the system to cluster semantically similar items. This is especially useful in applications where needs go beyond simple keyword matching, enabling the retrieval of items with similar meanings even if they are expressed differently [vectara_3].
#
# Overall, embeddings play a crucial role in enhancing the capabilities of modern retrieval systems by enabling them to perform semantic searches and deliver more contextually relevant results.
#
# --- Stream complete ---
